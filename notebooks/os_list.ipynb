# %%
import os
import pandas as pd
path = "D:\PACS\PACS_docx"

# Get list of files in the directory
file_list = os.listdir(path)

# Create a DataFrame with the file names
df = pd.DataFrame(file_list, columns=['File Name'])

# Save the DataFrame as an Excel file
df.to_excel('file_list.xlsx', index=False)
df
# Out:
#                       File Name
# 0      1028 LGUT Session 5.docx
# 1      1077 KMCC Session 4.docx
# 2      1097 JKEN Session 3.docx
# 3       1099 RMAL Session .docx
# 4      1102 JBOV Session 3.docx
# ..                          ...
# 74      811 TSPE Session 5.docx
# 75      813 ATRA Session 5.docx
# 76      822 SPOO Session 6.docx
# 77      999 SHER Session 5.docx
# 78  D A1 1299 CSHA Session.docx
#
# [79 rows x 1 columns]
